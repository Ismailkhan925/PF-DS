# %%
import pandas as pd

# %%
df=pd.read_csv("movie.csv")
df
# Out:
#                                            title    year  color  \
# 0                                         Avatar  2009.0  Color
# 1       Pirates of the Caribbean: At World's End  2007.0  Color
# 2                                        Spectre  2015.0  Color
# 3                          The Dark Knight Rises  2012.0  Color
# 4     Star Wars: Episode VII - The Force Awakens     NaN    NaN
# ...                                          ...     ...    ...
# 4911                     Signed Sealed Delivered  2013.0  Color
# 4912                               The Following     NaN  Color
# 4913                        A Plague So Pleasant  2013.0  Color
# 4914                            Shanghai Calling  2012.0  Color
# 4915                           My Date with Drew  2004.0  Color
#
#      content_rating  duration      director_name  director_fb  \
# 0             PG-13     178.0      James Cameron          0.0
# 1             PG-13     169.0     Gore Verbinski        563.0
# ...

# %%
df.loc[df['imdb_score']>6|(df['imdb_score']<8.1) ,['title','actor1','actor2','imdb_score']]
# Out:
#                                            title           actor1  \
# 0                                         Avatar      CCH Pounder
# 1       Pirates of the Caribbean: At World's End      Johnny Depp
# 2                                        Spectre  Christoph Waltz
# 3                          The Dark Knight Rises        Tom Hardy
# 4     Star Wars: Episode VII - The Force Awakens      Doug Walker
# ...                                          ...              ...
# 4911                     Signed Sealed Delivered      Eric Mabius
# 4912                               The Following      Natalie Zea
# 4913                        A Plague So Pleasant      Eva Boehnke
# 4914                            Shanghai Calling        Alan Ruck
# 4915                           My Date with Drew      John August
#
#                 actor2  imdb_score
# 0     Joel David Moore         7.9
# 1        Orlando Bloom         7.1
# 2         Rory Kinnear         6.8
# ...

# %%
act=df.loc[df['actor2_fb']>11000|(df['actor2_fb']<300),['title','actor2_fb']]
act.head(10)
# Out:
#                                         title  actor2_fb
# 0                                      Avatar      936.0
# 1    Pirates of the Caribbean: At World's End     5000.0
# 2                                     Spectre      393.0
# 3                       The Dark Knight Rises    23000.0
# 4  Star Wars: Episode VII - The Force Awakens       12.0
# 5                                 John Carter      632.0
# 6                                Spider-Man 3    11000.0
# 7                                     Tangled      553.0
# 8                     Avengers: Age of Ultron    21000.0
# 9      Harry Potter and the Half-Blood Prince    11000.0

# %%
sorted_data=df.sort_values('director_name')
sorted_data.set_index('director_name')
# Out:
#                                title    year  color content_rating  duration  \
# director_name
# A. Raven Cruz    The Helix... Loaded  2005.0  Color              R      97.0
# Aaron Hann                    Circle  2015.0  Color      Not Rated      87.0
# Aaron Schneider              Get Low  2009.0  Color          PG-13     100.0
# Aaron Seltzer             Date Movie  2006.0  Color          PG-13      85.0
# Abel Ferrara             The Funeral  1996.0  Color              R      99.0
# ...                              ...     ...    ...            ...       ...
# NaN                           Heroes     NaN  Color          TV-14      60.0
# NaN                      Home Movies     NaN  Color          TV-PG      22.0
# NaN                       Revolution     NaN  Color          TV-14      43.0
# NaN                     Happy Valley     NaN  Color          TV-MA      58.0
# NaN                    The Following     NaN  Color          TV-14      43.0
#
# ...
